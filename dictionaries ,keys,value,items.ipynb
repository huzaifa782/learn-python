# %% [markdown]
# ## 1 Reverse function in list

# %%
veg_list = ['onion', 'patato', 'tomato']

# %%
veg_list
# Out:
# ['onion', 'patato', 'tomato']

# %%
veg_list.extend(['lady finger', 'lemon'])

# %%
veg_list
# Out:
# ['onion',
#  'patato',
#  'tomato',
#  ['lady finger', 'lemon'],
#  'lady finger',
#  'lemon',
#  'lady finger',
#  'lemon']

# %%
veg_list.reverse()

# %%
veg_list
# Out:
# ['lemon',
#  'lady finger',
#  'lemon',
#  'lady finger',
#  ['lady finger', 'lemon'],
#  'tomato',
#  'patato',
#  'onion']

# %%
var = 'madam'

# %%
var == var[::-1]
# Out:
# True

# %%
list = ['huzaifa', 'mehmood']

# %%
list
# Out:
# ['huzaifa', 'mehmood']

# %%
list.reverse()

# %%
list
# Out:
# ['mehmood', 'huzaifa']

# %%
name = 'huzaifa'

# %%
name = name[::-1]

# %%
name
# Out:
# 'afiazuh'

# %% [markdown]
# ## Dictionaries

# %%
customer1_dict = {'first_name': 'Huzaifa',
                  'last_name': 'Mehmood',
                  'phone_num': '0333223323',      
                  'weight': 65,
                  'age': 21,
                 }

# %%
customer1_dict
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood',
#  'phone_num': '0333223323',
#  'weight': 65,
#  'age': 21}

# %%
type(customer1_dict)
# Out:
# dict

# %%
customer1_dict['last_name'] = 'Mehmood Alam Khan'

# %%
customer1_dict
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood Alam Khan',
#  'phone_num': '0333223323',
#  'weight': 65,
#  'age': 21}

# %%
customer_name = ['huzaifa', 'mehmood']

# %%
customer_name
# Out:
# ['huzaifa', 'mehmood']

# %%
customer_name[1] = 'mehmood alam'

# %%
customer_name
# Out:
# ['huzaifa', 'mehmood alam']

# %%
customer_name.insert(0, 'huzaofaaa')

# %%
customer_name
# Out:
# ['huzaofaaa', 'huzaifa', 'mehmood alam']

# %%
customer1_dict
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood Alam Khan',
#  'phone_num': '0333223323',
#  'weight': 65,
#  'age': 21}

# %%
del(customer1_dict['phone_num'])

# %%
customer1_dict
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood Alam Khan',
#  'weight': 65,
#  'age': 21}

# %%
customer1_dict1 = customer1_dict.copy()

# %%
customer1_dict1
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood Alam Khan',
#  'weight': 65,
#  'age': 21}

# %%
customer1_dict
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood',
#  'phone_num': '0333223323',
#  'weight': 65,
#  'age': 21}

# %%
customer1_dict1
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood Alam Khan',
#  'weight': 65,
#  'age': 21}

# %%
customer1_dict
# Out:
# {'first_name': 'Huzaifa',
#  'last_name': 'Mehmood',
#  'phone_num': '0333223323',
#  'weight': 65,
#  'age': 21}

# %%
for key, value in customer1_dict.items():
    print(f"{key} = {value}")
# Out:
# first_name = Huzaifa
# last_name = Mehmood
# phone_num = 0333223323
# weight = 65
# age = 21

# %%
for key in customer1_dict.keys():
    print(f"{key} ")
# Out:
# first_name
# last_name
# phone_num
# weight
# age

# %%
for value in customer1_dict.values():
    print(f"{value} ")
# Out:
# Huzaifa
# Mehmood
# 0333223323
# 65
# 21

# %%
f_name = ["Huzaifa", "Talha", "Huraira"]
l_name = ["Mehood"]
full_name = [] 
for a_f_name in f_name:
    for a_l_name in l_name:
        full_name.append(a_f_name+" "+ a_l_name)

# %%
print(full_name)
# Out:
# ['Huzaifa Mehood', 'Talha Mehood', 'Talha Mehood', 'Talha Mehood', 'Talha Mehood', 'Talha Mehood', 'Talha Mehood', 'Huraira Mehood']

# %%
customer1_dict.get('last_name', 'no addres found  ')
# Out:
# 'Mehmood'

# %% [markdown]
# ## set

# %%
name = 'Huzaifa', 'Talha', 'Huraira'

# %%
last_name = 'mehmood'

# %%
new_name = dict.fromkeys(name,last_name)

# %%
new_name
# Out:
# {'Huzaifa': 'mehmood', 'Talha': 'mehmood', 'Huraira': 'mehmood'}

# %%
type(new_name)
# Out:
# dict

# %%
first_name = 'huzaifa', 'talha'

# %%
last_name = 'mehmood'

# %%
full_name = dict.fromkeys(first_name,last_name)

# %%
full_name
# Out:
# {'huzaifa': 'mehmood', 'talha': 'mehmood'}

# %%
full_name[2] = 'orangi town'

# %%
full_name
# Out:
# {'huzaifa': 'mehmood', 'talha': 'mehmood', 2: 'orangi town'}

# %%
full_name[3] = 'huzaifa mehmood'

# %%
full_name
# Out:
# {'huzaifa': 'mehmood',
#  'talha': 'mehmood',
#  2: 'orangi town',
#  'first_name': 'huzaifa mehmood',
#  3: 'huzaifa mehmood'}

# %%
del(full_name[3])

# %%
full_name
# Out:
# {'huzaifa': 'mehmood',
#  'talha': 'mehmood',
#  2: 'orangi town',
#  'first_name': 'huzaifa mehmood'}

# %%
del(full_name["first_name"])

# %%
full_name
# Out:
# {'huzaifa': 'mehmood', 'talha': 'mehmood', 2: 'orangi town'}

# %%
dict = {'huzaifa' , 'work in crown textile', 'live in karachi'}

# %%
dict
# Out:
# {'huzaifa', 'live in karachi', 'work in crown textile'}

# %%
self_dict = {'Name' : 'Huzaifa',
             'Father_name': 'Mehmoo Alam Khan',
             'phone_num' : "03199029020",
             'cnic' : 4210103002,
            }

# %%
self_dict
# Out:
# {'Name': 'Huzaifa',
#  'Father_name': 'Mehmoo Alam Khan',
#  'phone_num': '03199029020',
#  'cnic': 4210103002}

# %%
self_dict.insert(0, 'cource : pythoprogrmming')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 self_dict.insert(0, 'cource : pythoprogrmming')
#
# AttributeError: 'dict' object has no attribute 'insert'
