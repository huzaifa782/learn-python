# %%
dict = {
{"customer id" : " 1",
    "first_name" : "Huzaifa",
    "last_name" : "Mehmood",
    "Address" : "orangi town",
},
{ "customer id" : " 2",
    "first_name" : "Talha",
    "last_name" : "Mehmood",
    "Address" : "North town",
},
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dict = {
#       2 {
#       3     "customer id" : " 1",
#       4     "first_name" : "Huzaifa",
#       5     "last_name" : "Mehmood",
#       6     "Address" : "orangi town",
#       7 },
#       8 {
#       9     "customer id" : " 2",
#      10     "first_name" : "Talha",
#      11     "last_name" : "Mehmood",
#      12     "Address" : "North town",
#      13 },
#      14 }
#
# TypeError: unhashable type: 'dict'

# %%
 customers = {
{
 "customer id": 0,
 "first name":"John",
 "last name": "Ogden",
 "address": "301 Arbor Rd.",
 },
 {
 "customer id": 1,
 "first name":"Ann",
 "last name": "Sattermyer",
 "address": "PO Box 1145",
 },
 {
 "customer id": 2,
 "first name":"Jill",
 "last name": "Somers",
 "address": "3 Main St.",
 },
20 }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 customers = {
#       2 {
#       3 "customer id": 0,
#       4 "first name":"John",
#       5 "last name": "Ogden",
#       6 "address": "301 Arbor Rd.",
#       7 },
#       8 {
#       9 "customer id": 1,
#      10 "first name":"Ann",
#      11 "last name": "Sattermyer",
#      12 "address": "PO Box 1145",
#      13 },
#      14 {
#      15 "customer id": 2,
#      16 "first name":"Jill",
#      17 "last name": "Somers",
#      18 "address": "3 Main St.",
#      19 },
#      20 20 }
#
# TypeError: unhashable type: 'dict'

# %% [markdown]
# ### FUNCTION

# %%
2+2
# Out:
# 4

# %%
num1 = int(input("Enter number 1: "))
num2 = int(input("Enter number 2: "))

num1 + num2
# Out:
# Enter number 1: 2
# Enter number 2: 4
# 6

# %%
obtain_marks = bio, chem, math, phy
bio = int(input("Enter marks bio: "))
chem = int(input("Enter marks chem: ")) 
math = int(input("Enter marks math: "))
phy = int(input("Enter marks phy: "))

calculate_percentage(bio, chem, math,phy)
# Out:
# Enter marks bio: 88
# Enter marks chem: 66
# Enter marks math: 77
# Enter marks phy: 55
# PERCENTAGE is 52.96296296296296

# %%
def calculate_percentage(bio, chem, math, phy):
    total_marks = 540
    obtain_marks = bio+chem+math+phy
    percentage = (obtain_marks * 100)/ total_marks
    print(f"PERCENTAGE is {percentage}")

# %%
calculate_percentage(87, 66, 87, 87)
# Out:
# PERCENTAGE is 60.55555555555556

# %%
student_grades = {"Student 1" : 100,
                "Student 2" : 87,
                 "Student 3" : 76,
                 "Student 4" : 67,
                 "Student 5" : 87}

# %%
student_grades
# Out:
# {'Student 1': 100,
#  'Student 2': 87,
#  'Student 3': 76,
#  'Student 4': 67,
#  'Student 5': 87}

# %%
total_grades = sum(student_grades.values())
number_of_student = len(student_grades)
average_grades = total_grades / number_of_student

print("STUDENT GRADES" , student_grades )
print("NUMBER OF STUDENT" , number_of_student )
print("TOTAL GRADES" , total_grades )
print("AVERAGE GRADES" , average_grades )
# Out:
# STUDENT GRADES {'Student 1': 100, 'Student 2': 87, 'Student 3': 76, 'Student 4': 67, 'Student 5': 87}
# NUMBER OF STUDENT 5
# TOTAL GRADES 417
# AVERAGE GRADES 83.4

# %%
def calculate_percentage() :
    bio = int(input("Enter marks bio: "))
    chem = int(input("Enter marks chem: ")) 
    math = int(input("Enter marks math: "))
    phy = int(input("Enter marks phy: "))
    
    total_marks = 540
    obtain_marks = bio+chem+math+phy
    percentage = (obtain_marks * 100)/ total_marks
    print(f"PERCENTAGE is {percentage}")

# %%
calculate_percentage()
# Out:
# Enter marks bio: 45
# Enter marks chem: 44
# Enter marks math: 65
# Enter marks phy: 55
# PERCENTAGE is 38.7037037037037

# %% [markdown]
# ### Task area of square

# %%
def calc_area():
    len_square = int(input("Enter the length : "))
    calc_area = len_square * len_square
    print(f" The area of square is {calc_area} sq.units")

# %%
 calc_area()
# Out:
# Enter the length : 8
#  The area of square is 64 sq.units

# %%
def area(length, breath, height):
    area = length * breath / height
    print(f" The area {area} is equal to sq.meter")

# %%
area(98, 56, 76)
# Out:
#  The area 72.21052631578948 is equal to sq.meter

# %%
def area(length, breath, height):
    area = length * breath / height
    return area

# %%
area(98, 56, 76)
# Out:
# 72.21052631578948

# %%
def name(first_name, middle_name, last_name):
    print(f"{first_name} {middle_name} {last_name}")

# %%
name("huzaifa" , "bin" , "mehmood")
# Out:
# huzaifa bin mehmood

# %%
def name(first_name, last_name, middle_name= ""):
    print(f"{first_name} {middle_name} {last_name}")

# %%
name("huzaifa" , "bin" , "mehmood")
# Out:
# huzaifa mehmood bin

# %%
word = ['apple', 'banana', 'apple', 'orange', 'banana', 'grape', 'apple']

if
