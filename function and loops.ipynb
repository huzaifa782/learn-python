# %%
print("my name is huzaifa", end = "")
print("mehmood", end ="")
print("alam khan")
# Out:
# my name is huzaifamehmoodalam khan

# %%
def name(first_name, midddle_name, last_name):

# %%
name()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 name()
#
# TypeError: name() missing 3 required positional arguments: 'first_name', 'midddle_name', and 'last_name'
