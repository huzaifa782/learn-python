# %%
importance = 0
Veg_type = input("Enter Vegetable type (Fresh/Not Fresh)")
Veg_price = input("Enter Vegetable price (High/Low)")

if Veg_type == "Fresh" :
    importance =10
elif Veg_price == "High":
    impotance = -5
else:
    print('Go To Next Shop')
    
print(importance)
# Out:
# Enter Vegetable type (Fresh/Not Fresh)Fresh
# Enter Vegetable price (High/Low)Low
# 10

# %% [markdown]
# ## <= is less than or equal to

# %% [markdown]
# num1 = int(input("Enter Number:"))

# %%
num1 = int(input("Enter Number:"))
# Out:
# Enter Number:10

# %%
num1 > 8
# Out:
# True

# %%
num = 0
(num > 10) and (num !=5)
# Out:
# False

# %%
15 != 10
# Out:
# True

# %%
15 != 15
# Out:
# False

# %%
num = int(input("Enter number"))
if num %2==0:
    print("even number")
else:
    print("odd number")
# Out:
# Enter number5
# odd number

# %%
unit = int(input("Enter unit : "))
rate_per_unit = 22.5
total_bill = unit * rate_per_unit
print(f"total bill amount in Rs{total_bill}")
# Out:
# Enter unit : 332
# total bill amount in Rs7470.0

# %%
year = int(input("Enter a year: "))
if year % 4 == 0:
    print(f"its a laeap year {year}")
else:
    print('its not a leap year')
# Out:
# Enter a year: 5
# its not a leap year

# %%
marks = int(input("enter marks: "))
if marks < 25:
    grade = "f"
elif 25 <=  marks < 40:
    grade = "c"
elif 40 <= marks < 60:
    grade = "b"
elif 60 <=  marks < 70:
    grade = "a"
else: 
    grade = "A+"
    print("grade", grade)
# Out:
# enter marks: 90
# grade A+
